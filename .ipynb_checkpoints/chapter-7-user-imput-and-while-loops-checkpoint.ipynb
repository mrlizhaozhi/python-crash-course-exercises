# %% [markdown]
# # Chapter 7. User Imput and while Loops

# %% [markdown]
# 7-1. Rental Car: Write a program that asks the user what kind of rental car they would like. Print a message about that car, such as "Let me see if I can find you a Subaru."

# %%
cars = input("What kind of rental car do you like? ")
print(f"Let me see if I can find you a {cars}.")
# Out:
# What kind of rental car do you like? Audi
# Let me see if I can find you a Audi.

# %% [markdown]
# 7-2. Restaurant Seating: Write a program that asks the user how many people are in their dinner group. If the answer is more than eight, print a message saying they’ll have to wait for a table. Otherwise, report that their table is ready.

# %%
dinner_group = input("How many people are there in your dinner group? ")
if (int(dinner_group) > 8):
	print("You will need to wait for a table.")
else:
	print("Your table is ready.")
# Out:
# How many people are there in your dinner group? 30
# You will need to wait for a table.

# %% [markdown]
# 7-3. Multiples of Ten: Ask the user for a number, and then report whether the number is a multiple of 10 or not.

# %%
number = input("Enter a number: ")
if (int(number) % 10 == 0):
	print("This number is a multiple of 10.")
else:
	print("This number is NOT a multiple of 10.")
# Out:
# Enter a number: 2
# This number is NOT a multiple of 10.

# %% [markdown]
# 7-4. Pizza Toppings: Write a loop that prompts the user to enter a series of pizza toppings until they enter a 'quit' value. As they enter each topping, print a message saying you’ll add that topping to their pizza.

# %%
prompt = "Enter some toppings. When you're finished, enter 'quit' to exit: "
toppings = " "
while toppings != "quit":
	toppings = input(prompt)
	if(toppings != "quit"):
		print(f"We will add {toppings} to your pizza.")
# Out:
# Enter some toppings. When you're finished, enter 'quit' to exit: tomato
# We will add tomato to your pizza.
# Enter some toppings. When you're finished, enter 'quit' to exit: eggs
# We will add eggs to your pizza.
# Enter some toppings. When you're finished, enter 'quit' to exit: vegitables
# We will add vegitables to your pizza.
# Enter some toppings. When you're finished, enter 'quit' to exit: quit

# %% [markdown]
# 7-5. Movie Tickets: A movie theater charges different ticket prices depending on a person’s age. If a person is under the age of 3, the ticket is free; if they are between 3 and 12, the ticket is $10; and if they are over age 12, the ticket is $15. Write a loop in which you ask users their age, and then tell them the cost of their movie ticket.

# %%
flag = True
prompt = "What's your age? (Type 'quit' to exit.) "
message = ''
while flag:
	message = input(prompt)
	if(message == 'quit'):
		flag = False
	else:
		if(int(message) < 3):
			print("The ticket is free.")
		elif(3 < int(message) < 12):
			print("The ticket is $10.")
		else:
			print("The ticket is $15.")
# Out:
# What's your age? (Type 'quit' to exit.) 22
# The ticket is $15.
# What's your age? (Type 'quit' to exit.) 1
# The ticket is free.
# What's your age? (Type 'quit' to exit.) 60
# The ticket is $15.
# What's your age? (Type 'quit' to exit.) 80
# The ticket is $15.
# What's your age? (Type 'quit' to exit.) 8
# The ticket is $10.
# What's your age? (Type 'quit' to exit.) quit

# %% [markdown]
# 7-6. Three Exits: Write different versions of either Exercise 7-4 or Exercise 7-5 that do each of the following at least once:
# • Use a conditional test in the while statement to stop the loop.
# • Use an active variable to control how long the loop runs.
# • Use a break statement to exit the loop when the user enters a 'quit' value.

# %%
prompt = "Enter a number or type 'quit' to exit: "
message = " "
while True:
	message = input(prompt)
	if(message == 'quit'):
		break
	else:
		if(int(message) > 10):
			print(f"{message} is greater than 10.")
		else:
			print(f"{message} is smaller than 10.")
# Out:
# Enter a number or type 'quit' to exit: 1
# 1 is smaller than 10.
# Enter a number or type 'quit' to exit: 10
# 10 is smaller than 10.
# Enter a number or type 'quit' to exit: 11
# 11 is greater than 10.
# Enter a number or type 'quit' to exit: quit

# %% [markdown]
# 7-7. Infinity: Write a loop that never ends, and run it. (To end the loop, press ctrl-C or close the window displaying the output.)

# %%
i = 1
while i < 2:
	print("infinite loop running")
# Out:
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# ...
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# infinite loop running
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\ZHAOZH~1\AppData\Local\Temp/ipykernel_12072/93624459.py in <module>
#       1 i = 1
#       2 while i < 2:
# ----> 3         print("infinite loop running")
#
# C:\Anaconda\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     527             is_child = (not self._is_master_process())
#     528             # only touch the buffer in the IO thread to avoid races
# --> 529             self.pub_thread.schedule(lambda: self._buffer.write(string))
#     530             if is_child:
#     531                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# C:\Anaconda\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     212             self._events.append(f)
#     213             # wake event thread (message content is ignored)
# --> 214             self._event_pipe.send(b'')
#     215         else:
#     216             f()
#
# C:\Anaconda\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     545                 )
#     546             data.group = group
# --> 547         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     548
#     549     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket._send_copy()
#
# C:\Anaconda\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %% [markdown]
# 7-8. Deli: Make a list called sandwich_orders and fill it with the names of various sandwiches. Then make an empty list called finished_sandwiches. Loop through the list of sandwich orders and print a message for each order, such as I made your tuna sandwich. As each sandwich is made, move it to the list of finished sandwiches. After all the sandwiches have been made, print a message listing each sandwich that was made.

# %%
sandwich_orders = ['chicken', 'beef', 'eggs']
finished_sandwiches = []
for sandwich in sandwich_orders:
	print(f"I made you a {sandwich} sandwich.")
	finished_sandwiches.append(sandwich)
print("The following sandwiches are finished:")
for finished_sandwich in finished_sandwiches:
	print("\t" + finished_sandwich)
# Out:
# I made you a chicken sandwich.
# I made you a beef sandwich.
# I made you a eggs sandwich.
# The following sandwiches are finished:
# 	chicken
# 	beef
# 	eggs

# %% [markdown]
# 7-9. No Pastrami: Using the list sandwich_orders from Exercise 7-8, make sure the sandwich 'pastrami' appears in the list at least three times. Add code near the beginning of your program to print a message saying the deli has run out of pastrami, and then use a while loop to remove all occurrences of 'pastrami' from sandwich_orders. Make sure no pastrami sandwiches end up in finished_sandwiches.

# %%
sandwich_orders = ['chicken', 'beef', 'eggs', 'pastrami', 'tuna', 'pastrami', 'pastrami']
while 'pastrami' in sandwich_orders:
	sandwich_orders.remove('pastrami')
print(sandwich_orders)
print("Oops, we have run out of pastrami!")
# Out:
# ['chicken', 'beef', 'eggs', 'tuna']
# Oops, we have run out of pastrami!

# %% [markdown]
# 7-10. Dream Vacation: Write a program that polls users about their dream vacation. Write a prompt similar to If you could visit one place in the world, where would you go? Include a block of code that prints the results of the poll.

# %%
flag = True
vacation = {}
while flag:
	name = input("What's your name? ")
	place = input("Where would you like to visit? ")

	vacation[name] = place

	repeat = input("Would you like to take this poll again? (yes/no) ")
	if(repeat == 'no'):
		flag = False
for name, place in vacation.items():
	print(f"{name.title()} wish to visit {place.title()}")
# Out:
# What's your name? Li Zhaozhi
# Where would you like to visit? Los Angeles
# Would you like to take this poll again? (yes/no) no
# Li Zhaozhi wish to visit Los Angeles
